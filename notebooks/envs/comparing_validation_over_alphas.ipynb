# %% [markdown]
# # Comparing validation results from Projected PPO policy over different alphas

# %%
from rl_vcf.validate.utils import load_scenario_database

# %%
alpha_1_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/17-24-17/task_policy_db.pkl"
)
fig, ax = alpha_1_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_1_db.get_num_successes())
print(alpha_1_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 932 932 932]
# 137.1587982832618

# %%
alpha_1_02_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/17-52-43/task_policy_db.pkl"
)
fig, ax = alpha_1_02_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_1_02_db.get_num_successes())
print(alpha_1_02_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 931 931 931]
# 136.12781954887217

# %%
alpha_1_1_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/18-23-57/task_policy_db.pkl"
)
fig, ax = alpha_1_1_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_1_1_db.get_num_successes())
print(alpha_1_1_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 934 934 934]
# 135.0353319057816

# %%
alpha_1_5_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/18-51-02/task_policy_db.pkl"
)
fig, ax = alpha_1_5_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_1_5_db.get_num_successes())
print(alpha_1_5_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 901 901 901]
# 124.99223085460599

# %%
alpha_10_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/19-21-01/task_policy_db.pkl"
)
fig, ax = alpha_10_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_10_db.get_num_successes())
print(alpha_10_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 672 672 672]
# 111.58035714285714

# %%
alpha_100_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/19-49-59/task_policy_db.pkl"
)
fig, ax = alpha_100_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_100_db.get_num_successes())
print(alpha_100_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 485 485 485]
# 106.9340206185567

# %%
alpha_1000_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/20-18-30/task_policy_db.pkl"
)
fig, ax = alpha_1000_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_1000_db.get_num_successes())
print(alpha_1000_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 435 435 435]
# 105.17701149425288

# %%
alpha_10000_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/20-46-44/task_policy_db.pkl"
)
fig, ax = alpha_10000_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_10000_db.get_num_successes())
print(alpha_10000_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 418 418 418]
# 105.12918660287082

# %%
alpha_task_db = load_scenario_database(
    "../../src/rl_vcf/outputs/2024-12-20/16-51-57/base_policy_db.pkl"
)
fig, ax = alpha_task_db.plot_epsilons(
    plot_empirical=True,
    confs=[0.9999999],
)
print(alpha_task_db.get_num_successes())
print(alpha_task_db.get_mean_successful_time_taken())
# Out:
# [  0   0   0 ... 398 398 398]
# 104.90954773869346
